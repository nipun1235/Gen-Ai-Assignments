# %% [markdown]
# # Lists and Tuples
#
# # Product Collection

# %% [markdown]
# ## Task 1
#
# 1. Create a list named product conataining at least 6 product names(strings)

# %%
products_list=["Milk","Butter","Soap","Facewash","Ketchup","Curd"]

# %%
products_list
# Out:
# ['Milk', 'Butter', 'Soap', 'Facewash', 'Ketchup', 'Curd']

# %% [markdown]
# ###
# 2. Create a tuple named sample_product that stores(product_name,price,category) for one product

# %%
sample_product=("Milk",80,"Dairy Product")

# %% [markdown]
# ###
# 3. Print the 2nd and last product from the list.

# %%
products_list[-1]
# Out:
# 'Curd'

# %%
products_list[1]
# Out:
# 'Butter'

# %% [markdown]
# ###
# 4. Append two new product names to the products and then print the updated list.

# %%
products_list.append("Wheat")

# %%
products_list.append("Buiscuit")

# %%
products_list
# Out:
# ['Milk', 'Butter', 'Soap', 'Facewash', 'Ketchup', 'Curd', 'Wheat', 'Buiscuit']

# %% [markdown]
# ### Extra(optional)
# convert sample_product into a list,change its price,and convert it back to a tuple

# %%
#conversion of tuple to list
product_list=list(sample_product)

# %%
product_list
# Out:
# ['Milk', 80, 'Dairy Product']

# %%
# To show that it is converted into list
type(product_list)
# Out:
# list

# %%
product_list[1]=97

# %%
product_list
# Out:
# ['Milk', 97, 'Dairy Product']

# %%
# conversion from list to tuple
sample_product=tuple(product_list)

# %%
sample_product
# Out:
# ('Milk', 97, 'Dairy Product')

# %%
type(sample_product)
# Out:
# tuple
