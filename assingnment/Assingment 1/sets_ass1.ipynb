# %% [markdown]
# # SETS
# ## Categories

# %% [markdown]
# ###
# 1. From your product list,create a set of categories called categories_set

# %%
products_list=["Milk","Butter","Soap","Facewash","Ketchup","Frooti"]

# %%
categories_set={"Dairy Product1","Dairy Product2","Bath","Face","Eatable","Cold Drink"}

# %%
categories_set
# Out:
# {'Bath', 'Cold Drink', 'Dairy Product1', 'Dairy Product2', 'Eatable', 'Face'}

# %% [markdown]
# ###
# 2. Demonstrate adding a new category to the set and show that duplicates are ignored

# %%
categories_set.add("Essentials")

# %%
categories_set
# Out:
# {'Bath',
#  'Cold Drink',
#  'Dairy Product1',
#  'Dairy Product2',
#  'Eatable',
#  'Essentials',
#  'Face'}

# %%
# Duplicates are ignored 
categories_set.add("Cold Drink")

# %%
categories_set
# Out:
# {'Bath',
#  'Cold Drink',
#  'Dairy Product1',
#  'Dairy Product2',
#  'Eatable',
#  'Essentials',
#  'Face'}

# %% [markdown]
# ###
# 3. Show how to check whether a category exists in the set (print a boolean result)

# %%
categories_set== FileExistsError
# Out:
# False

# %% [markdown]
# ### Extra Optional
#
# Show how to get the total number of unique categories using a set.

# %%
len(categories_set)
# Out:
# 8
