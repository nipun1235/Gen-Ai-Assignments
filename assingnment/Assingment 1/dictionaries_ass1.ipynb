# %% [markdown]
# # Dictionaries
# ## Product Pricing

# %% [markdown]
# ###
# 1. Create a dictionary price_dict where keys are product names and values are prices(integre or floats). Include at least 6 entries

# %%
price_dict={"Milk":90,
            "Ice cream":60,
            "Curd":50,
            "Rice":100,
            "Soap":75,
            "Buiscuit":30}

# %% [markdown]
# ### 2. Write small code block to:
# ### Add a new product with price to price_dict.
# ###   Update the price of an existing product
# ###   remove a product by name

# %%
# adding a new product with price
price_dict["Cream"]=98

# %%
price_dict
# Out:
# {'Milk': 90,
#  'Ice cream': 60,
#  'Curd': 50,
#  'Rice': 100,
#  'Soap': 75,
#  'Buiscuit': 30,
#  'Cream': 98}

# %%
price_dict.keys()
# Out:
# dict_keys(['Milk', 'Ice cream', 'Curd', 'Rice', 'Soap', 'Buiscuit', 'Cream'])

# %%
price_dict.values()
# Out:
# dict_values([100, 60, 50, 100, 75, 30, 98])

# %%
# update the price of an existing product
price_dict["Milk"]=110

# %%
price_dict
# Out:
# {'Milk': 110,
#  'Ice cream': 60,
#  'Curd': 50,
#  'Rice': 100,
#  'Soap': 75,
#  'Buiscuit': 30,
#  'Cream': 98}

# %%
# remove a prduct by name
del price_dict["Ice cream"]

# %%
price_dict
# Out:
# {'Milk': 110, 'Curd': 50, 'Rice': 100, 'Soap': 75, 'Buiscuit': 30, 'Cream': 98}

# %% [markdown]
# ###
# 3. Print the average price of all products

# %%
print(sum(price_dict.values()))
# Out:
# 463

# %%
avg_price=sum(price_dict.values())/len(price_dict)
print(avg_price)
# Out:
# 77.16666666666667

# %% [markdown]
# ###
# Extra ---> Print the product with both maximum and minimum value

# %%
max_price=max(price_dict, key=price_dict.get)
print(max_price)
# Out:
# Milk

# %%
min_price=min(price_dict, key=price_dict.get)
print(min_price)
# Out:
# Buiscuit
