# %% [markdown]
# # Combined Operation

# %% [markdown]
# ###
# 1. Using the product list and price_dict,create a list of tuples named catalog where each tuple is(product_name,price,category)

# %%
# catalog=(product_name,price,category)
catalog=("Milk",110,"Dairy Product",
        "Butter",85,"Dairy Product",
        "Soap",70,"Bath",
        "Facewash",75,"Selfcare")

# %% [markdown]
# ###
# 2. From catalog,create a new dictionary category_to_products that maps each category to a list of product names in that category

# %%
category_to_products={"Milk":"Dairy Product",
        "Butter":"Dairy Product",
        "Soap":"Bath",
        "Facewash":"Selfcare"}

# %% [markdown]
# ###
# 3. Print all products that belong to the category that has maximum number of Products.

# %%
products = list(category_to_products.values())
max_category = max(products, key=products.count)
print("Category with maximum products:", max_category)
for product in category_to_products:
    if category_to_products[product] == max_category:
        print(product)
# Out:
# Category with maximum products: Dairy Product
# Milk
# Butter
