# %% [markdown]
# # Task 1: Create a Simple Module(math_utlis.py)

# %% [markdown]
# ## Create a module math_utlis.py with the following functions:
# ### 1. add(a,b) --> returns a+b
# ### 2. subtract(a,b) --> returns a-b
# ### 3. square(n) --> returns n**2
# ### In main.py,import this module in two different ways:
# ### import math_utils
# ### from math_utlis import square

# %%
import math

# %%
from module_assingment.math_utlis import add

# %%
add(9,4)
# Out:
# 13

# %%
from module_assingment.math_utlis import subtract

# %%
subtract(10,99)
# Out:
# 89

# %%
from module_assingment.math_utlis import square

# %%
square(22)
# Out:
# 484

# %% [markdown]
# # Task 2: Create Another Module(string_utlis.py)
# ### 1. capitalize_words(text) --> returns text with each word capitalized
# ### 2. reverse_string(text) --> returns reversed string
# ### 3. word_count(text) --> returns number of words in the text

# %%
from module_assingment.mainpy.string_utlis import capitalize_words

# %%
capitalize_words("my name is nipun bhardwaj")
# Out:
# 'MY NAME IS NIPUN BHARDWAJ'

# %%
from module_assingment.mainpy.string_utlis import reverse_string

# %%
reverse_string("I am learning Generative AI")
# Out:
# 'IA evitareneG gninrael ma I'

# %%
from module_assingment.mainpy.string_utlis import word_count

# %%
word_count("This is my 5th assingment of this course")
# Out:
# 8

# %% [markdown]
# # Task 3: Create a Simple Package(shop_package)
# ## Inside folder shop_package/,create:
#
# ### discount.py
# ### Functions:
# ### 1. apply_discount(price,percent)--> returns discounted price
# ### 2. flat_discount(price) --> always subtracts 50 from price
#
# ### billing.py
# ### Functions:
# ### 1. calculate_total(price) --> returns total bill(sum of all prices)
# ### 2. apply_tax(amount) --> adds 5% tax
#
# ### __init__.py
# ### Leave it empty or add:
# ### from .discount import apply_discount,flat_discount
# ### from .billing import calculate_total,apply_tax

# %%
from shop_package.discount import apply_discount

# %%
apply_discount(3000,16)
# Out:
# 2520.0

# %%
from shop_package.discount import flat_discount

# %%
flat_discount(2590)
# Out:
# 2540

# %%
from shop_package.billing import calculate_total

# %%
calculate_total([1000,2650,3571,9831,970])
# Out:
# 18022

# %%
from shop_package.billing import apply_tax

# %%
apply_tax(18022)
# Out:
# 18923.1

# %% [markdown]
# # Task 4: Importing the Package in main.py
# ### Example usage:
# ### print(disc.apply_discount(1000,10))
# ### print(calculate_total([100,200,300]))

# %%
apply_discount(1000,10)
# Out:
# 900.0

# %%
calculate_total([100,200,300])
# Out:
# 600
